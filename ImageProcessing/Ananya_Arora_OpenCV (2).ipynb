# %%
from matplotlib import pyplot as plt
# !pip install opencv-python 
import matplotlib.pyplot as plt
import numpy as np

# %%
import cv2

# %%
img=cv2.imread('train.jpg',1)

# %%
resize=cv2.resize(img,(300,300))

# %%
cv2.imshow('train.jpg',resize)

# %%
cv2.waitKey(0)
# Out:
# 32

# %%
cv2.destroyAllWindows()
plt.imshow(resize)

# %%
print(img)
# Out:
# [[[  3   2  11]
#   [  5   4  13]
#   [  8  11  16]
#   ...
#   [153 194 239]
#   [144 185 230]
#   [136 178 223]]
#
#  [[  9   8  17]
#   [ 12  11  20]
#   [  9  12  17]
#   ...
#   [146 187 232]
#   [141 182 227]
#   [128 170 215]]
#
#  [[  9   9  15]
#   [ 11  11  17]
#   [  8  11  16]
#   ...
#   [143 184 229]
#   [142 183 228]
#   [143 184 229]]
#
#  ...
#
#  [[  2   1  11]
#   [  2   1  11]
#   [  2   1  11]
#   ...
#   [  8  68  74]
#   [  5  67  73]
#   [  0  62  66]]
#
#  [[  1   0  10]
#   [  2   1  11]
#   [  2   1  10]
#   ...
#   [ 11  69  74]
#   [  8  69  73]
#   [  0  60  64]]
#
#  [[  1   0  10]
#   [  1   0  10]
#   [  2   1  10]
#   ...
#   [ 10  68  73]
#   [ 12  70  75]
#   [  0  57  61]]]

# %%
print(img.shape)
# Out:
# (2886, 4681, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
img7 = cv2.imread('children.jpg')
gray = cv2.cvtColor(img7, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img7 = cv2.rectangle(img7,(x,y),(x+w,y+h),(255,0,0),2)
    img7 = cv2.putText(img7, 'human', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
cv2.imshow('img',img7)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img7)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
img8 = cv2.imread('people.jpg')
gray = cv2.cvtColor(img8, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img8 = cv2.rectangle(img8,(x,y),(x+w,y+h),(255,0,0),2)
    img8 = cv2.putText(img8, 'human', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
cv2.imshow('img',img8)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img8)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
img9 = cv2.imread('couple.jpg')
gray = cv2.cvtColor(img9, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img9 = cv2.rectangle(img9,(x,y),(x+w,y+h),(255,0,0),2)
    img9= cv2.putText(img9, 'human', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

# %%
cv2.imshow('img',img9)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(img9)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
img10 = cv2.imread('woman.jpg')
gray = cv2.cvtColor(img10, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img10 = cv2.rectangle(img10,(x,y),(x+w,y+h),(255,0,0),2)
    img10= cv2.putText(img10, 'human', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
cv2.imshow('img',img10)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(img10)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
img11 = cv2.imread('children2.jpg')
gray = cv2.cvtColor(img11, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img11 = cv2.rectangle(img11,(x,y),(x+w,y+h),(255,0,0),2)
    img11= cv2.putText(img11, 'human', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
cv2.imshow('img',img11)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(img11)
